# %% [markdown]
# <center>
#   <div style="font-family: Arial, sans-serif; background-color: #72a0e5; color: #2D2926; padding: 12px; line-height: 1; font-size: 32px; font-weight: bold;">
#     Creating Test Datasets for the Churn Detection App
#   </div>
# </center>

# %% [markdown]
# In this file, we create separate test datasets for churn and non-churn cases to make it easier for users to test specific scenarios in the app. This improves usability by allowing direct access to each case type without the need to search through mixed data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load dataset
churn_df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv", na_values=(' '))

# Select features
churn_df = churn_df[['tenure', 'MonthlyCharges', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
                     'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 
                     'PaymentMethod', 'Churn']]

# Split the dataset into features and target
X = churn_df.drop(columns=['Churn'])
y = churn_df['Churn']

# Split into training and testing sets with stratification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Recreate the complete test dataframe
test_df = pd.concat([X_test, y_test], axis=1)

# Separate churned and non-churned customers in the test set
test_churn_yes = test_df[test_df['Churn'] == 'Yes']
test_churn_yes = test_churn_yes.sample(n=100, random_state=42)

test_churn_no = test_df[test_df['Churn'] == 'No']
test_churn_no = test_churn_no.sample(n=100, random_state=42)

# %%
test_churn_yes
# Out:
#       tenure  MonthlyCharges MultipleLines InternetService OnlineSecurity  \
# 139        1           70.45            No     Fiber optic             No
# 1644      34          109.80           Yes     Fiber optic            Yes
# 3408       4           50.70            No             DSL             No
# 6866       1           95.45           Yes     Fiber optic             No
# 2686      19           79.85           Yes     Fiber optic             No
# ...      ...             ...           ...             ...            ...
# 2168       7           74.40           Yes     Fiber optic             No
# 6142      42           50.25           Yes             DSL             No
# 7011       4           60.40            No             DSL            Yes
# 4393      21           86.50           Yes     Fiber optic             No
# 642        1           89.55            No     Fiber optic             No
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 139            No               No          No          No              No
# 1644          Yes              Yes          No         Yes             Yes
# 3408          Yes               No          No          No              No
# 6866           No               No          No         Yes             Yes
# 2686           No              Yes          No          No              No
# ...           ...              ...         ...         ...             ...
# 2168           No               No          No          No              No
# 6142           No               No          No          No              No
# 7011          Yes               No         Yes          No              No
# 4393           No               No          No          No             Yes
# 642            No               No          No         Yes             Yes
#
#             Contract            PaymentMethod Churn
# 139   Month-to-month             Mailed check   Yes
# 1644  Month-to-month             Mailed check   Yes
# 3408  Month-to-month  Credit card (automatic)   Yes
# 6866  Month-to-month         Electronic check   Yes
# 2686  Month-to-month         Electronic check   Yes
# ...              ...                      ...   ...
# 2168  Month-to-month             Mailed check   Yes
# 6142  Month-to-month         Electronic check   Yes
# 7011  Month-to-month             Mailed check   Yes
# 4393  Month-to-month         Electronic check   Yes
# 642   Month-to-month         Electronic check   Yes
#
# [100 rows x 13 columns]

# %%
test_churn_no
# Out:
#       tenure  MonthlyCharges     MultipleLines InternetService  \
# 1648      60           80.95               Yes     Fiber optic
# 4633      72           24.05               Yes              No
# 5302      10           65.50                No             DSL
# 5619      20           91.00                No     Fiber optic
# 2760      26           20.65                No              No
# ...      ...             ...               ...             ...
# 2982      52           20.85                No              No
# 4249      10           65.90                No             DSL
# 4577      62          104.85               Yes     Fiber optic
# 1461      22           95.90               Yes     Fiber optic
# 6530      63           36.10  No phone service             DSL
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 1648                  Yes                   No                   No
# 4633  No internet service  No internet service  No internet service
# 5302                   No                  Yes                   No
# 5619                   No                   No                   No
# 2760  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 2982  No internet service  No internet service  No internet service
# 4249                   No                  Yes                  Yes
# 4577                  Yes                   No                  Yes
# 1461                  Yes                   No                   No
# 6530                  Yes                   No                   No
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 1648                   No                   No                   No
# 4633  No internet service  No internet service  No internet service
# 5302                  Yes                   No                  Yes
# 5619                   No                  Yes                  Yes
# 2760  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 2982  No internet service  No internet service  No internet service
# 4249                   No                   No                  Yes
# 4577                   No                  Yes                  Yes
# 1461                  Yes                  Yes                   No
# 6530                  Yes                   No                   No
#
#             Contract              PaymentMethod Churn
# 1648  Month-to-month           Electronic check    No
# 4633        Two year  Bank transfer (automatic)    No
# 5302  Month-to-month           Electronic check    No
# 5619        One year  Bank transfer (automatic)    No
# 2760        One year    Credit card (automatic)    No
# ...              ...                        ...   ...
# 2982        One year    Credit card (automatic)    No
# 4249        One year               Mailed check    No
# 4577        One year           Electronic check    No
# 1461  Month-to-month    Credit card (automatic)    No
# 6530        One year  Bank transfer (automatic)    No
#
# [100 rows x 13 columns]

# %%
## Save the datasets to Excel files
# test_churn_yes.to_excel("test_churn_yes.xlsx", index=False)
# test_churn_no.to_excel("test_churn_no.xlsx", index=False)
